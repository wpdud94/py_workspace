# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# # 1. 데이터 불러오기

# %%
# 상반기 주유소 판매 데이터 불러오기
first = pd.read_csv('../data/2019년 상반기 주유소 판매가격.csv', encoding='cp949')
first
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 90585  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190626  GS칼텍스   셀프
# 90586  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190627  GS칼텍스   셀프
# 90587  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190628  GS칼텍스   셀프
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
second = pd.read_csv('../data/2019년 하반기 주유소 판매가격.csv', encoding='cp949')
second
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
# 상반기 판매가격 데이터 프레임 결측치 조회
first.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %%
# 하반기 판매가격 데이터 프레임 결측치 조회
second.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %% [markdown]
# # 2. 데이터 결합

# %%
# 상반기와 하반기 데이터를 상하로 결합
df = pd.concat([first,second])
df
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %% [markdown]
# # 3. 데이터 가공 및 분석

# %%
# 데이터 프레임 정보 조회
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181714 entries, 0 to 91123
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  int64
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 16.6+ MB

# %%
# 상표 컬럼의 고유값 조회
df['상표'].unique()
# Out:
# array(['SK에너지', 'GS칼텍스', 'S-OIL', '현대오일뱅크', '알뜰주유소', 'NH-OIL', '알뜰(ex)',
#        '자가상표'], dtype=object)

# %%
# 지역 컬럼의 고유값 조회
df['지역'].unique()
# Out:
# array(['서울 강남구', '서울 강동구', '서울 강북구', '서울 강서구', '서울 관악구', '서울 광진구',
#        '서울 구로구', '서울 금천구', '서울 노원구', '서울 도봉구', '서울 동대문구', '서울 동작구',
#        '서울 마포구', '서울 서대문구', '서울 서초구', '서울 성동구', '서울 성북구', '서울 송파구',
#        '서울 양천구', '서울 영등포구', '서울 용산구', '서울 은평구', '서울 종로구', '서울 중구',
#        '서울 중랑구'], dtype=object)

# %%
# 지역 컬럼의 값을 이용하여 시와 구를 분리
df['시']=[str(region.split(' ')[0]) for region in df['지역']]
df['구']=[str(region.split(' ')[1]) for region in df['지역']]
df.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유   시    구
# 0   1673  1465  1365     0  서울  강남구
# 1   1673  1465  1365     0  서울  강남구
# 2   1673  1465  1365     0  서울  강남구
# 3   1673  1465  1365     0  서울  강남구
# 4   1673  1465  1365     0  서울  강남구

# %%
# 시 컬럼의 서울을 서울특별시로 변환
df['시'][(df['시']=='서울')] = '서울특별시'
df['시'].unique()
# Out:
# C:\kjy\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array(['서울특별시'], dtype=object)

# %%
# 기간 컬럼을 datetime 형식으로 변경
df['기간'] = pd.to_datetime(df['기간'],format='%Y%m%d')
df.head()
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구
# 0   1673  1465  1365     0  서울특별시  강남구
# 1   1673  1465  1365     0  서울특별시  강남구
# 2   1673  1465  1365     0  서울특별시  강남구
# 3   1673  1465  1365     0  서울특별시  강남구
# 4   1673  1465  1365     0  서울특별시  강남구

# %%
# 기간 컬럼에서 dt 타입을 이용하여 년, 월, 일, 요일 컬럼 생성
# df['년']=df['기간'].dt.year
df['월']=df['기간'].dt.month
df['일']=df['기간'].dt.day
df['요일']=df['기간'].dt.day_name()

df
# Out:
#              번호      지역             상호              주소         기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
# ...         ...     ...            ...             ...        ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스   셀프
#
# ...

# %%
# 휘발유 가격이 비싼 5개 판매가격을 출력하세요.
df.sort_values('휘발유',ascending=False).head()
# Out:
#              번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 86620  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-24  SK에너지   일반   2649
# 86626  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 86627  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 86621  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 86622  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
#
#         휘발유    경유  실내등유      시   구   월   일         요일
# 86620  2356  2196     0  서울특별시  중구   9  24    Tuesday
# 86626  2356  2196     0  서울특별시  중구   9  30     Monday
# 86627  2356  2196     0  서울특별시  중구  10   1    Tuesday
# 86621  2356  2196     0  서울특별시  중구   9  25  Wednesday
# 86622  2356  2196     0  서울특별시  중구   9  26   Thursday

# %%
# 휘발유 가격이 저렴한 5개 판매가격을 출력하세요. (단 휘발유가 0원인 데이터는 제외)
df[df['휘발유']>0].sort_values('휘발유').head()
# Out:
#              번호      지역                   상호                    주소         기간  \
# 13148  A0033328  서울 강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30 2019-02-07
# 82475  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-31
# 82474  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-30
# 82476  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-02-01
# 82998  A0000690  서울 은평구    지에스칼텍스(주)수색뉴타운주유소  서울 은평구 수색로 350 (수색동) 2019-01-26
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유      시    구  월   일         요일
# 13148  SK에너지   셀프   1788  1255  1155     0  서울특별시  강서구  2   7   Thursday
# 82475  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  1  31   Thursday
# 82474  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  1  30  Wednesday
# 82476  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2   1     Friday
# 82998  GS칼텍스   셀프      0  1265  1165     0  서울특별시  은평구  1  26   Saturday

# %%
# 상표별 평균 휘발유 가격을 계산하세요.
mean_gasolin = df.groupby(by='상표')[['휘발유']].mean()
mean_gasolin.columns = ['mean']
mean_gasolin
# Out:
#                mean
# 상표
# GS칼텍스   1564.029014
# NH-OIL  1449.088889
# S-OIL   1532.302882
# SK에너지   1612.147153
# 알뜰(ex)  1431.347945
# 알뜰주유소   1447.875902
# 자가상표    1492.085540
# 현대오일뱅크  1515.458244

# %%
# 상표별 평균 휘발유 가격을 시각화하세요.
mean_gasolin.plot(kind='bar')
plt.show()

# %%
# 상표와 셀프여부별 평균 휘발유 가격을 계산하세요.
by_logo_self=df.pivot_table(values='휘발유',index=['상표','셀프여부'], aggfunc=np.mean)
by_logo_self.columns=['mean']
by_logo_self
# Out:
#                     mean
# 상표     셀프여부
# GS칼텍스  셀프    1481.410074
#        일반    1610.060123
# NH-OIL 일반    1449.088889
# S-OIL  셀프    1481.437428
#        일반    1579.451162
# SK에너지  셀프    1504.853863
#        일반    1690.377765
# 알뜰(ex) 셀프    1431.347945
# 알뜰주유소  셀프    1434.726027
#        일반    1455.372511
# 자가상표   셀프    1494.409449
#        일반    1491.740351
# 현대오일뱅크 셀프    1483.546767
#        일반    1534.254225

# %%
# 상표와 셀프여부별 평균 휘발유 가격을 시각화하세요.
by_logo_self.plot(kind='bar')
plt.ylabel('평균 휘발유 가격')
plt.ylim(1400,1750)
plt.show()

# %%
# 셀프여부에 따라 휘발유 가격을 boxplot으로 시각화해보세요.
# 휘발유가 0인 데이터는 제외하고 시각화합니다
plt.figure(figsize=(10,6))
sns.boxplot('셀프여부','휘발유',data=df[df['휘발유']>0])
plt.ylabel('평균 휘발유 가격')
plt.show()

# %%
# 휘발유 가격과 일반 주유소의 가격을 boxplot을 이용하여 시각화해보세요.
# 휘발유가 0인 데이터는 제외하고 시각화합니다.
plt.figure(figsize=(10,6))
sns.boxplot(y='휘발유',x='상표',hue='셀프여부',data=df[df['휘발유']>0])
plt.ylabel('평균 휘발유 가격')
plt.ylim(1200,2400)
plt.show()

# %%
# 지역별 평균 휘발유 가격을 계산하세요
mean_gasolin_by_gu = df.groupby(by='구')[['휘발유']].mean()
mean_gasolin_by_gu.columns=['mean']
mean_gasolin_by_gu.sort_values('mean',ascending=False)
# Out:
#              mean
# 구
# 중구    1976.948052
# 용산구   1882.049825
# 종로구   1838.554945
# 강남구   1713.093581
# 마포구   1689.755616
# 성동구   1583.659561
# 서초구   1577.131304
# 강동구   1576.685264
# 영등포구  1568.279506
# 노원구   1531.221551
# 서대문구  1528.943332
# 구로구   1525.410383
# 송파구   1518.957954
# 관악구   1518.128564
# 양천구   1512.890261
# 동작구   1512.470911
# 성북구   1507.948267
# 동대문구  1506.833542
# 도봉구   1494.171062
# 광진구   1490.597054
# 강서구   1488.818088
# 은평구   1481.964026
# 금천구   1477.121992
# 중랑구   1469.009092
# 강북구   1453.517525

# %%
# 지역별 평균 휘발유 가격을 시각화하세요.
plt.figure(figsize=(11,8))
mean_gasolin_by_gu.sort_values('mean',ascending=False).plot(kind='bar')
plt.ylabel('평균 휘발유 가격')
plt.ylim(1400,2000)
plt.show()

# %%
# 월별 평균 휘발유 가격을 계산하세요
mean_gasolinn_by_month = df.groupby(by='월')[['휘발유']].mean()
mean_gasolinn_by_month
# Out:
#             휘발유
# 월
# 1   1466.554672
# 2   1446.624956
# 3   1465.159889
# 4   1519.481056
# 5   1606.096255
# 6   1605.343367
# 7   1585.726529
# 8   1589.339464
# 9   1633.125891
# 10  1634.464547
# 11  1620.687606
# 12  1630.535819

# %%
# 월별 평균 휘발유 가격을 시각화 하세요.
plt.figure(num=5,figsize=(10,6))

mean_gasolinn_by_month.plot(kind='line')
plt.ylabel('평균 휘발유 가격(원)')
plt.ylim(1400,1700)
plt.show()

# %%
# pivot_table 함수를 이용하여 구와 월 컬럼을 이용하여 평균 휘발유 가격을 계산하세요
mean_gasolinn_by_gu_month=df.pivot_table(values='휘발유',index='구',columns='월',aggfunc=np.mean)
mean_gasolinn_by_gu_month
# Out:
# 월              1            2            3            4            5   \
# 구
# 강남구   1619.865825  1600.945536  1616.143548  1666.350000  1739.208232
# 강동구   1503.383302  1478.109244  1468.138277  1526.341667  1605.267206
# 강북구   1357.002488  1345.565934  1342.990074  1414.246154  1500.025126
# 강서구   1376.357474  1370.397959  1392.716129  1447.910749  1543.218433
# 관악구   1429.822262  1405.984127  1403.370510  1456.301230  1548.151210
# 광진구   1379.168459  1362.851190  1388.360215  1451.507407  1547.330341
# 구로구   1418.589124  1408.949675  1427.221408  1477.038052  1566.923642
# 금천구   1360.297767  1337.986264  1371.192982  1438.646154  1529.620347
# 노원구   1406.245161  1397.600000  1421.683871  1484.722222  1586.740175
# 도봉구   1373.606112  1365.634951  1390.093190  1451.424861  1545.358423
# 동대문구  1414.227273  1400.508117  1421.432551  1472.259091  1559.993874
# 동작구   1414.339806  1390.377698  1401.193548  1454.729097  1529.654839
# ...

# %%
# pivot_table 함수를 이용하여 구와 월 컬럼을 이용하여 평균 휘발유 가격을 시각화 하세요 (heatmap 이용)
plt.figure(figsize=(20,10))
sns.heatmap(mean_gasolinn_by_gu_month.round())
plt.grid()

# %%
# 기름 데이터 중 0 지우기
df_nozero = df[(df['휘발유']>0)&(df['고급휘발유']>0)&(df['경유']>0)]
df_nozero
# Out:
#              번호      지역             상호              주소         기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
# ...         ...     ...            ...             ...        ...    ...  ...
# 90935  A0009180  서울 중랑구  지에스칼텍스㈜ 대원주유소  서울 중랑구 동일로 600 2019-12-27  GS칼텍스   셀프
# 90936  A0009180  서울 중랑구  지에스칼텍스㈜ 대원주유소  서울 중랑구 동일로 600 2019-12-28  GS칼텍스   셀프
# 90937  A0009180  서울 중랑구  지에스칼텍스㈜ 대원주유소  서울 중랑구 동일로 600 2019-12-29  GS칼텍스   셀프
# 90938  A0009180  서울 중랑구  지에스칼텍스㈜ 대원주유소  서울 중랑구 동일로 600 2019-12-30  GS칼텍스   셀프
# 90939  A0009180  서울 중랑구  지에스칼텍스㈜ 대원주유소  서울 중랑구 동일로 600 2019-12-31  GS칼텍스   셀프
#
# ...

# %%
# 월별 기름 데이터 만들기
mean_oil_by_month=df_nozero.groupby('월').mean().iloc[:,:3]
mean_oil_by_month

# 월별 기름 변화량 데이터
mean_oil_by_month['고급휘발유L1']=mean_oil_by_month['고급휘발유'].shift(1)
mean_oil_by_month['휘발유L1']=mean_oil_by_month['휘발유'].shift(1)
mean_oil_by_month['경유L1']=mean_oil_by_month['경유'].shift(1)
mean_oil_by_month['고급휘발유증가율']=(mean_oil_by_month['고급휘발유']-mean_oil_by_month['고급휘발유L1'])/mean_oil_by_month['고급휘발유L1']*100
mean_oil_by_month['휘발유증가율']=(mean_oil_by_month['휘발유']-mean_oil_by_month['휘발유L1'])/mean_oil_by_month['휘발유L1']*100
mean_oil_by_month['경유증가율']=(mean_oil_by_month['경유']-mean_oil_by_month['경유L1'])/mean_oil_by_month['경유L1']*100

mean_oildelta_by_month = mean_oil_by_month.iloc[:,6:]
mean_oildelta_by_month
# Out:
#     고급휘발유증가율    휘발유증가율     경유증가율
# 월
# 1        NaN       NaN       NaN
# 2  -0.728055 -1.211948 -1.053360
# 3   0.641088  1.158160  1.170964
# 4   2.037602  3.335472  3.215079
# 5   3.479796  4.954402  4.185825
# 6   0.190346  0.236828  0.130693
# 7  -0.731567 -0.973236 -1.019919
# 8  -0.151914  0.318122  0.306130
# 9   1.544092  2.418451  2.065574
# 10 -0.146309 -0.070996 -0.227230
# 11 -0.659427 -0.972450 -1.239036
# 12 -0.028147  0.408808  0.035797

# %%
# 월별 전체 기름 평균 가격 추이
mean_oil_by_month.iloc[:,:3].plot()
plt.title('월별 전체 기름 평균 가격 추이')
plt.show()

# %%
mean_oildelta_by_month.plot()
plt.title('월별 전체 기름 증가율 추이')
plt.show()

# %%
# sns.lmplot('셀프여부','휘발유',data=df[df['휘발유']>0])

# %%
# 전처리 : 셀프와 일반 데이터 처리
mean_gasolin_self=df[(df['휘발유']>0)&(df['셀프여부']=='셀프')]['휘발유'].mean()
mean_gasolin_normal=df[(df['휘발유']>0)&(df['셀프여부']=='일반')]['휘발유'].mean()

# %%
plt.hist('휘발유',data=df[(df['휘발유']>0)&(df['셀프여부']=='셀프')],histtype='step', bins=50, label='셀프')#log=True
plt.hist('휘발유',data=df[(df['휘발유']>0)&(df['셀프여부']=='일반')],histtype='step', bins=50, label='일반')
plt.axvline(x=mean_gasolin_self, color='b')
plt.axvline(x=mean_gasolin_normal, color='orange')
plt.legend()
plt.xlabel('휘발유 가격')
plt.ylabel('빈도')
plt.title('셀프여부에 따른 휘발유 가격 분포도')
plt.show()

# %%
# 월별 기름 변동성 데이터
std_oil_month=df_nozero.groupby(['월','셀프여부']).std()
std_oil_month=std_oil_month.reset_index()
# 셀프만, 일반만
std_oil_month_self = std_oil_month.reset_index()[std_oil_month.reset_index()['셀프여부']=='셀프'].iloc[:,1:6]
std_oil_month_normal = std_oil_month.reset_index()[std_oil_month.reset_index()['셀프여부']=='일반'].iloc[:,1:6]
# 월별 가솔린 변동성
std_gasoline_month_self = std_oil_month.reset_index()[std_oil_month.reset_index()['셀프여부']=='셀프'].loc[:,'휘발유']
std_gasoline_month_normal = std_oil_month.reset_index()[std_oil_month.reset_index()['셀프여부']=='일반'].loc[:,'휘발유']

# %%
# 월별 기름 셀프&일반 변동성 그래프
# std_oil_month_self.plot(x='월')
# std_oil_month_normal.plot(x='월')
std_oil_month[std_oil_month['셀프여부']=='일반'].iloc[:,:5].plot(x='월')
plt.title('일반')
std_oil_month[std_oil_month['셀프여부']=='셀프'].iloc[:,:5].plot(x='월')
plt.title('셀프')
plt.show()

# %%
pop=pd.read_csv('../data/주민등록인구_시도_시_군_구__20200715190007.csv',encoding='cp949')
pop.head()
# Out:
#      구     인구수
# 0  종로구  151290
# 1   중구  126171
# 2  용산구  228670
# 3  성동구  300889
# 4  광진구  351350

# %%
mean_oil_by_gu=df_nozero.groupby('구').mean()
mean_oil_by_gu=mean_oil_by_gu.reset_index()
mean_oil_by_gu_withpop=pd.merge(mean_oil_by_gu,pop,on=pop['구'])
mean_oil_by_gu_withpop.rename(columns={'구_x':'구'})
sns.lmplot('인구수','휘발유',data=mean_oil_by_gu_withpop)
sns.lmplot(y='고급휘발유',x='인구수',data=mean_oil_by_gu_withpop)
sns.lmplot(y='경유',x='인구수',data=mean_oil_by_gu_withpop)

# %%
mean_oil_by_gu_withpop
# Out:
#    key_0   구_x        고급휘발유          휘발유           경유         실내등유         월  \
# 0    종로구   강남구  1954.139255  1740.763019  1605.317732   367.977752  6.545237
# 1     중구   강동구  1879.030665  1620.780167  1475.721625   812.576663  6.593787
# 2    용산구   강북구  1794.046191  1468.881686  1346.333874     0.000000  6.959481
# 3    성동구   강서구  1717.093794  1466.557396  1340.064862   354.667522  6.533131
# 4    광진구   관악구  1775.159582  1527.861298  1402.375093   615.566741  6.884415
# 5   동대문구   광진구  1763.386821  1496.229782  1357.990158   416.161746  7.155755
# 6    중랑구   구로구  1697.796778  1505.017348  1355.754647     0.000000  7.188352
# 7    성북구   금천구  1636.901099  1454.546703  1323.739011  1040.796703  6.513736
# 8    강북구   노원구  1746.931507  1513.015342  1387.384658   786.774247  6.526027
# 9    도봉구   도봉구  1798.624829  1496.569959  1374.983539  1026.128258  6.531550
# 10   노원구  동대문구  1750.256176  1527.897530  1384.887466     0.000000  6.524245
# ...

# %%
mean_oil_by_gu_withpop.corr()
# Out:
#           고급휘발유       휘발유        경유      실내등유         월         일       인구수
# 고급휘발유  1.000000  0.954127  0.951888  0.197734 -0.272927 -0.240580  0.381310
# 휘발유    0.954127  1.000000  0.998624  0.177830 -0.210966 -0.161126  0.397684
# 경유     0.951888  0.998624  1.000000  0.188902 -0.217639 -0.167036  0.391663
# 실내등유   0.197734  0.177830  0.188902  1.000000 -0.333341 -0.407524  0.082914
# 월     -0.272927 -0.210966 -0.217639 -0.333341  1.000000  0.923877  0.017431
# 일     -0.240580 -0.161126 -0.167036 -0.407524  0.923877  1.000000  0.100798
# 인구수    0.381310  0.397684  0.391663  0.082914  0.017431  0.100798  1.000000
